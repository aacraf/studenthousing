# %%
import feedparser
import pprint
import requests 
import pandas as pd
import numpy as np

# %%
# Listado de data sets disponible en opendata   
parameters = {'rows': '1000'}

url = 'http://opendata-ajuntament.barcelona.cat/data/api/3/action/package_search'
response = requests.get(url,params=parameters)
# Incluimos a tabla pandas Data sets contienen diferentes fuentes de datos columna resources
catalogo = pd.DataFrame(response.json()['result']['results']) 

print(catalogo.code.unique())
# Creamos tabla con las fuentes de datos del catalogo

i = 0
for index, row in catalogo.iterrows():
    if i== 0:
        fuente_datos = pd.DataFrame(row['resources']) 
        fuente_datos['code'] = row['code']   
    i = 1
    aux =  pd.DataFrame(row['resources'])
    aux['code'] = row['code']
    fuente_datos = fuente_datos.append(aux)
fuente_datos = fuente_datos[['code','size', 'description', 'format' , 'downloads_absolute', 'token_required', 'url',  'name']]
# Out:
# ['np-piscines' ' np-molls' 'np-platges' 'np-quioscs-tramits'
#  'np umbracles' 'np-jardins interiors illa' 'np-jardins-botanics'
#  'np-espais-gimnastica' 'np-plantes depuradores ' 'np-esculleres'
#  'np-illes-vianants' 'np-circuits-caminar-correr'
#  'np-nasia-diposits-aigues-pluvials' 'np-nasia-miradors'
#  'np-nasia-fossars' 'aut-terrasses-excep-decret_21_5'
#  'xarxa-refugis-climatics' 'consolats-bcn' 'arees-esbarjo-gossos-bcn'
#  'renda-disponible-llars-bcn' 'NP-ASIA_DipositsVehicles_BCN'
#  'bancs-del-temps-bcn' 'lloguer-de-vehicles' 'funiculars' 'teleferics'
#  'estacions maritimes' 'administracio estatal' 'comissaries policia'
#  'galeries comercials' 'grans establiments' 'grans centres comercials'
#  'tanatoris' 'cementiris' 'administracio autonomica'
#  'administracio municipal'
#  'SUBVENCIONS_A_ENS_PUBLICS-NO-INTEGRATS-CERCADOR-POST 2019'
#  'arbrat parcs' 'estat-ports-recarrega-electric'
#  'informacio-punts-recarrega-electric'
#  'autenticacions-punts-recarrega-electric' 'Enquesta_Escletxa_Digital'
#  'Est_Vehicles_Amb_Distintiu'
#  'EBSIB_BCN_Enquesta_Benestar_Subjectiu_Infancia'
#  'Est_Vehicles_Antiguitat_Tipus'
#  "Subvencions atorgades per l'Ajuntament de Barcelona"
#  'Edificis Amics de la Bici Barcelona' 'capacitat-mapa-estrategic-soroll'
#  'poblacio-exposada-mapa-estrategic-soroll' 'mapes-immissio-qualitat-aire'
#  'isofones-mapa-estrategic-soroll' 'tramer-mapa-estrategic-soroll'
#  'allotjaments-pensions' 'allotjaments-hotels' 'allotjaments-altres'
#  'mediambient puntsrobaamiga' 'mediambient contenidorssal'
#  'mediambient puntsrecollidaarbresnadal' 'Estacionaments DUM'
#  'Zones Estacionament Zona BUS' 'indicadors_covid19_bcn'
#  'corredors_bici_bcn' 'ampliacio_voreres_bici_bcn'
#  'carrers pacificats bici bcn' 'laterals tallats transit bici bcn'
#  'nomenclator-bcn' 'metadades-variables-est-meteocat'
#  'mediambient puntsverdsbarri' 'mediambient puntsverdsmobils'
#  'mediambient puntverdcolaborador' 'mapa_peuat'
#  'CENS- ACTIVITATS-ECONOMIQUES-CLASS-BCN' 'LÍMITS MUNICIPALS DISTRICTES'
#  'Cataleg_Costos_BCNROC' 'culturailleure-espaismusicacopes'
#  'culturailleure-bibliotequesimuseus' 'culturailleure-espaisinfantils'
#  'culturailleure-parcsjardins'
#  'culturailleure-espaisparticipaciociutadana'
#  'culturailleure-cinemesteatresauditoris'
#  'renda_tributaria_per_persona_atlas_distribucio'
#  'renda_tributaria_unitat_consum_atlas_distribucio' 'esports equip'
#  'esports individuals' 'esports instal-lacions esportives'
#  'Est_Cadastre_Carrecs_Tipus_Propietari' 'accessibilitat via_pública'
#  'VIATGES_GOV_BCN' 'mesures estacions meteorologiques'
#  'metadades estacions meteorologiques'
#  'Est_Cadastre_Carrecs_Quota_Cadastral' 'precipitacio hist bcn'
#  'temperatures hist bcn' 'Cataleg_Registre-Estudis-Informes_BCNROC'
#  'Cataleg_Informes_Avaluacio_BCNROC' 'Cataleg_Havana_BCNROC'
#  'Cataleg_Documents_Alcaldes_BCNROC'
#  'Cataleg_Declaracions_Institucionals_BCNROC'
#  'qualificacions elements urbanistics ' 'patrimoni-arquitectonic-protegit'
#  'ESM_BCN_EVO' 'Est_Cadastre_Edificacions_Superficie'
#  'Est_Cadastre_Edificacions_Edat_Mitjana'
#  'Est_Cadastre_Edificacions_Nombre_Locals'
#  'Est_Cadastre_Carrecs_Valors_Cadastrals' 'Est_Cadastre_Carrecs_Us'
#  'Est_Cadastre_Edificacions_Any_Const' 'Est_Cadastre_Finques_Superficie'
#  'Est_Cadastre_Finques_Regim_Propietat'
#  'Est_Cadastre_Habitatges_Valor_Cadastral'
#  'Est_Cadastre_Habitatges_Edat_Mitjana'
#  'Est_Cadastre_Habitatges_Superficie_Mitjana' 'Actes Anella'
#  'terrasses vigents' 'EVOLUCIO_DESPESES_PER_UNITATS_ORGÀNIQUES'
#  'EVOLUCIO_RESULTAT_INGRESSOS_I_DESPESES'
#  'EVOLUCIO_DESPESES_CORRENTS_PER_POLÍTIQUES'
#  'EVOLUCIO_INGRESSOS_PER_CAPÍTOLS'
#  'EVOLUCIO_DESPESES_PER_CAPÍTOLS_I_ARTICLES'
#  'EVOLUCIO_INGRESSOS_PER_CAPÍTOLS_I_ARTICLES'
#  'EVOLUCIO_DESPESES_PER_CAPÍTOLS' 'educacio ensenyament infantil'
#  'educacio ensenyament no reglat' 'educacio ensenyament reglat'
#  'sanitat farmacies' 'sanitat serveis sanitaris'
#  'sanitat hospitals atencio primaria'
#  'Informació Rutes Autobus Estació Barcelona Nord'
#  'Est_Eleccions_Generals_Seccio_Censal'
#  'Est_Mercat_Immobiliari_Compravenda_Sup'
#  'Est_Mercat_Immobiliari_Compravenda'
#  'Est_Mercat_Immobiliari_Lloguer_Mitja_Mensual'
#  'Est_Mercat_Immobiliari_Compravenda_Preu_Total'
#  'Contaminants_estacions_mesura_qualitat_aire' 'Estat Estacions Bicing  '
#  'Informacio Estacions Bicing  ' 'espais prioritaris neteja barcelona'
#  'subvencions transferencies cultura' 'dades globals cultura'
#  'FONTS_ORNAMENTALS' 'equipaments culturals icub'
#  'Est_Padro_Domicilis_Sexe'
#  'Est_Padro_Domicilis_Nacionalitat_Espanyola_Estrangera'
#  'Est_Demo_Canvi_Domicili' 'SIU Area Blava' 'barcelona-activa-subvencions'
#  'Est_Demo_Altes_Omissio' 'CONTRACTES_MENORS_A_GENÈRICA'
#  'PRÒRROGUES_DE_CONTRACTES' 'serveissocials puntsassessoramentenergetic'
#  'serveissocials centresdiagentgran'
#  'serveissocials centresserveissocials'
#  'serveissocials residenciesgentgran'
#  'serveissocials puntsinformacioiatenciodones'
#  'serveissocials equipsatencioinfanciaadolescencia'
#  'ServeisSocials_MenjadorsSocials' 'serveissocials-oficinesbenestarsocial'
#  'serveissocials habitatgestutelats' 'infraestructures-inventari-reserves'
#  'infraestructures-M-reserves' 'infraestructures-inventari-semafors'
#  'infraestructures-tipologia-semafors'
#  'infraestructures-tipologia-inscripcions'
#  'infraestructures-inventari-pas-vianants'
#  'infraestructures-inventari-inscripcions'
#  'infraestructures-tipologia-pas-vianants'
#  'infraestructures-inventari-senyals' 'infraestructures-inventari-suports'
#  'infraestructures-tipologia-senyals'
#  'Est_Demo_Canvi_Domicili_Nacionalitat' 'aforaments descriptiu'
#  'aforament tipus equipament' 'aforaments detall'
#  'aparcaments-sota-superficie' 'Est_Padró_Ocupació_Mitjana'
#  'qualitat_aire_detall' 'qualitat_aire_estacions_BCN'
#  'Ús del servei Bicing' 'dades xarxa biblioteques catalunya' 'Arbrat zona'
#  'horaris aparcaments superficie' 'trams aparcament superficie'
#  'tarifes aparcament superficie' 'colors aparcaments superficie'
#  'Cataleg_Revistes_BCNROC' 'Cataleg_Publicacions_BCNROC'
#  'Cataleg_Bases_Us_Espai_Public_BCNROC' 'Cataleg_Dictamens_BCNROC'
#  'Cataleg_Fotografies_Edificis_BCNROC' 'Cataleg_Plans_Especials_BCNROC'
#  'Cataleg_Reglaments_BCNROC' 'Cataleg_Directrius_BCNROC'
#  'Cataleg_Fotografies_Elements_Urbans_BCNROC'
#  'Cataleg_Bases_Ajuts_Subvencions_BCNROC' 'Catàleg_Enquestes_BCNROC'
#  'Cataleg_Estatuts_BCNROC' 'Cataleg_Dossiers_Notes_Premsa_BCNROC'
#  'Cataleg_Decrets_Alcaldia_BCNROC' 'Cataleg_Mesures_Govern_BCNROC'
#  'Cataleg_Documents_Tecnics_BCNROC' 'Cataleg_Laudes_BCNROC'
#  'Cataleg_Memories_BCNROC' 'Cataleg_Fotografies_Projectes_Urbans_BCNROC'
#  'Cataleg_Fotografies_Barcelona_General_BCNROC' 'Cataleg_Comptes_BCNROC'
#  'Cataleg_BCNROC' 'Cataleg_Ordenances_Municipals_BCNROC'
#  'Cataleg_Fotografies_Art_Public_BCNROC' 'Cataleg_Protocols_BCNROC'
#  'Cataleg_Premis_BCNROC' 'Cataleg_Plans_Estrategics_BCNROC'
#  'Cataleg_Fotografies_Cementiris_BCNROC' 'Cataleg_Instruccions_BCNROC'
#  'Cataleg_Informes_Diversos_BCNROC' 'Cataleg_Circulars_BCNROC'
#  'Cataleg_Informes_Organs_Govern_BCNROC' 'Cataleg_Pressupostos_BCNROC'
#  'Cataleg_cartes-de-serveis-i-politiques-de-qualitat_BCNROC'
#  'Cataleg_Ordenances_Fiscals_Preus_BCNROC'
#  'punts critics neteja barcelona' 'Entitats Municipals'
#  'Est_Vehicles_Antiguitat_Menys_Un_Any' 'est-sp-taxa-bruta-mort-dones'
#  'est-sp-taxa-mort-dones-estand-edat' 'est-sp-taxa-mort-estand-edat'
#  'est-sp-taxa-mort-homes-estand-edat' 'est-sp-fec-mares-35-49-anys'
#  'est-sp-taxa-fec-mares-35-49-anys' 'est-sp-fec-mares-15-19-anys'
#  'est-sp-taxa-fec-mares-15-49-anys' 'est-sp-fec-mares-15-49-anys'
#  'est-sp-taxa-fec-mares-15-19-anys' 'est-sp-fec-mares-20-34-anys'
#  'est-sp-taxa-fec-mares-20-34-anys' 'est-sp-defuncions' 'est-sp-esp-vida'
#  'est-sp-esp-vida-homes' 'est-sp-esp-vida-dones' 'est-sp-defuncions-homes'
#  'est-sp-defuncions-dones' 'est-sp-taxa-bruta-mort'
#  'est-sp-taxa-bruta-mort-homes' '20170706_Districtes_Barris'
#  'Accions formatives adreçades al personal' 'Est_Noms_nadons'
#  'Est_Padro_50_Noms_Freqüents' 'Ronda Verda' 'Carrils Bici en Construcció'
#  'ZONES30_CARRERS' 'Carrils Bici Municipis' 'Vies Pedalables "Ciclables"'
#  'carril_bici' 'Est_Demo_Defuncions_Nacionalitat'
#  'Est_Demo_Canvi_Nacionalitat' 'Est_Demo_Defuncions_Lloc_Naixement'
#  'Est_Demo_Defuncions_Edat_Quinquennal'
#  'Est_Demo_Emigrants_Edat_Quinquennal'
#  'Est_Demo_Immigrants_Edat_Quinquennal'
#  'Est_Demo_Emigrants_Lloc_Destinacio'
#  'Est_Demo_Immigrants_Lloc_Procedencia'
#  'Est_Demo_Naixements_Lloc_Naixement'
#  'Est_Demo_Altes_Omissio_Nacionalitat' 'Est_Demo_Emigrants_Nacionalitat'
#  'Est_Demo_Immigrants_Nacionalitat'
#  'Est_Demo_Altes_Omissio_Lloc_Naixement' 'Est_Demo_Baixes_Edat_Quinquenal'
#  'Est_Demo_Baixes_Lloc_Naixement'
#  'Est_Demo_Canvi_Domicili_Edat_Mitjana_Poblacio'
#  'Est_Demo_Baixes_Nacionalitat' 'COBERTURA_VEGETAL_NDVI'
#  'Est_Padro_Alta_Padro_Sexe' 'IRIS'
#  'Est_Mercat_Immobiliari_Lloguer_Nombre_Contractes'
#  'Est_Mercat_Immobiliari_Lloguer_Superficie_Mitjana'
#  'CENS_ANIMALS_COMPANYIA' 'HABITATGES_US_TURISTIC' 'LLOCS_CULTE'
#  'CONTRACTES_MENORS' 'MODIFICACIÓ_DE_CONTRACTES'
#  'CAMPANYES_PUBLICITAT_INSTITUCIONAL' 'RESUMS_TRIMESTRALS_CONTRACTACIO'
#  'RELACIO_CONTRACTISTES' 'REGISTRE_DE_CONVENIS'
#  'INDICADORS_TRANSPARENCIA_PRESSUPOSTARIA' 'HORTS_URBANS'
#  'PLANTILLA_MUNICIPAL' 'MAPA_TOPONIMIA_WMS' 'MAPA_HIDROGRAFIA_OBRES_WMS'
#  'MAPA_AMBITS_URBANISTICS_WMS' 'MAPA_ENERGIA_TELECO_WMS'
#  'MAPA_OROGRAFIA_RELLEU_WMS' 'MAPA_VEGETACIO_WMS'
#  'MAPA_CONSTRUCCIONS_POBLAMENT_WMS' 'MAPA_USOS_SOL_WMS'
#  'MAPA_SERVEIS_PÚBLICS_WMS' 'MAPA_XARXA_TOPOGRAFICA_MUNICIPAL_WMS'
#  'MAPA_PLANOL_CIUTAT_BCN_WMS' 'MAPA_GRAF_VIARI_CARRERS_WMS'
#  'MAPA_ACUSTIC_WMS' 'SERVEI_CATALEG_METADADES_CSW'
#  'TRANSFERENCIES_ENCOMANES_GESTIO'
#  'SUBVENCIONS_I_TRANSFERENCIES_A_ENS_PUBLICS' 'CENTRES_CIVICS_ENTITATS'
#  'CENTRES_CIVICS_ACTIVITATSDIFUSIO' 'CENTRES_CIVICS_FORMACIO'
#  'MERCATS_MUNICIPALS' 'MERCATS_FIRES_CARRER' 'dades ateneus'
#  'dades projectes fabriques creacio'
#  'ESPAIS_CREACIO_FORMACIO_PROFESSIONALS'
#  'ESPAIS_CREACIO_ACTIVITATS_DIFUSIO' 'PROVISIO_PROMOCIO' 'OFERTA_PUBLICA'
#  'EVOLUCIO_DEUTE' 'COMPLIMENT_OBJECTIUS_ESTABILITAT'
#  'P_CONS_INICIALS_SEGONS_LGEP-LOEPSF' 'MODIFICACIONS_CREDIT_PRESSUPOST'
#  'DADES_SINDICALS' 'COMPATIBITLITATS' 'CONTENIDORS_RECICLATGE_OLIS'
#  'PRESSUPOST_INGRESSOS' 'PRESSUPOST_DESPESES' 'PARADES_DE_TAXI'
#  'APARCAMENTS_BCN' 'EQUIPAMENTS_RELACIONATS_AMB_TRANSPORTS'
#  'EQUIPAMENT_TRANSPORTS_I_SERVEIS_RELACIONATS' 'ACOLLIDA_ANIMALS'
#  'AGENDA_CULTURAL' 'ACCIDENTS_CAUSES_GU_BCN' 'ACCIDENTS_PERSONES_GU_BCN'
#  'ACCIDENTS_TIPUS_GU_BCN' 'ACCIDENTS_VEHICLES_GU_BCN'
#  'PUNTS_ANCORATGE_BICICLETES' 'BICICLETES' 'ZONES_CARREGA_DESCARREGA'
#  'APARCAMENTS_SERVEI_BICIS' 'ENTITAS_PACTE_ MOBILITAT' 'BENZINERES'
#  'TRANSPORTS_METROPOLITANTS_COMPANYIES_AUTOCARS_DE_BARCELONA'
#  'ESCALES_MECANIQUES' 'PUNTS_RECARREGA_VEHICLES_ELECTRICS' 'BICING'
#  'REGISTRE_ESTUDIS_I_INFORMES' 'CENS_ACTIVITATS_COMERCIALS'
#  'PATIS_ESCOLARS' 'DUTXES_PLATGES'
#  'CARRECS_ELECTES_COMISSIONATS_I_GERENTS' 'LAVABOS_PUBLICS'
#  'ACCIDENTS_GU_BCN' 'ORDENANCES_MUNICIPALS' 'INCIDENTS_GESTIONATS_GUB'
#  'Est_Social_Discapacitats_Sexe' 'Est_Social_Discapacitats_Tipus'
#  'Est_Social_Discapacitats_Grau' 'Est_Social_Discapacitats_Grups_Edat'
#  'ARBRES_INTERES_LOCAL' 'PUNTS_INFORMACIO_TURISTICA'
#  'Est_Cadastre_Habitatges_Superficie' 'Est_Cadastre_Habitatge_Propietari'
#  'Est_Cadastre_Habitatges_Any_Const' 'ENTITATS' 'FITXES_OCUPACIONALS'
#  'Est_Atur_Pes' 'Est_Vehicles_Nacionalitat_Propietari' 'ARBRAT_VIARI'
#  'HABIT_PPAL_SEGONS_REGIM_TIN' 'HABIT_FAM_SIT_EDIF_DEST_HABIT_SEGONS_TIP'
#  'HABIT_PPAL_SEGONS_SUP_UTIL' 'HABIT_PPAL_SEGONS_ANY_CONST'
#  'HABIT_PPAL_SEGONS_NOM_HABIT' 'HABIT_PPAL_SEGONS_INSTAL2_AIGUA'
#  'HABIT_PPAL_SEGONS_INSTAL3_TELF_I_INT'
#  'HABIT_PPAL_SEGONS_ESTAT_CONSERV_EDIF'
#  'HABIT_FAM_DEST_HABIT_SEGONS_ANY_CONST'
#  'HABIT_PPAL_SEGONS_NOMBRE_PERS_VIUEN' 'HABIT_PPAL_SEGONS_INSTAL1_CALEF'
#  'N_EDIF_HAB_SEGONS_ANY_CONSTRUC' 'N_EDIF_HAB_TIPUS_EDIF'
#  'IMMO_EDIF_HAB_SEGONS_ESTAT_CONSERVACIO'
#  'IMMO_EDIF_HAB_SEGONS_ANY_CONSTRUCCIO'
#  'IMMO_EDIF_HAB_SEGONS_NUM_PLANTES_SOBRE_RASANT'
#  'N_EDIF_HAB_SEGONS_ESTAT_CONS_EDIFICI' 'N_EDIF_HAB_SEGONS_N_IMMO'
#  'N_EDIF_HAB_SEGONS_N_PLANTES_SOTA_RASANT' 'N_EDIF_HAB_N_IMMO_EDIF'
#  'N_EDIF_HAB_SEGONS_NOMBRE_PLANTES' 'IMMO_EDIF_HAB_SEGONS_INSTALACIONS'
#  'N_EDIF_HAB_SEGONS_NOMBRE_PLANTES_SOBRE_RASANT'
#  'N_EDIF_HAB_SEGONS_N_PLANTES_SOBRE_RASANT'
#  'N_EDIF_HAB_SEGONS_NOMBRE_IMMO' 'N_EDIF_HAB_SEGONS_INSTAL'
#  'N_EDIF_HAB_SEGONS_N_PLACES_GAR'
#  'N_EDIF_HAB_SEGONS_NOMBRE_PLANTES_SOTA_RASANT'
#  'IMMO_EDIF_HAB_SEGONS_NUM_PLANTES_SOTA_RASANT' 'HABITATGES_2NA_MA'
#  'Est_Atur_Sexe' 'Est_Atur_Durada' 'AGENDA_ACTIVITATS_ESPORTIVES' 'OBRES'
#  'dades arxius' 'dades sales musica en viu'
#  'CENTRES_CIVICS_METRES_QUADRATS' 'DADES_MERCE' 'dades grans auditoris'
#  'DADES_FESTIVALS' 'DADES_FESTES_CIUTAT' 'CINEMES_DADES_GLOBALS'
#  'dades arts esceniques' 'LLISTA_EXPOSICIONS_TEMPORALS'
#  'DADES_FESTIVAL_GREC' 'dades_museus_exposicions'
#  'FABRIQUES_CREACIO_METRES_QUADRATS' 'Est_Demo_Defuncions_Sexe'
#  'FONTS_BEURE' 'DIVTER' 'CARRERER' 'PERFIL_CONTRACTANT' 'cataleg-cartobcn'
#  'Prediccio_meteorologica_del_barcelones' 'PUNTS_WIFI' 'ESTACIONS_BUS'
#  'TRANSPORTS' 'locllo-evolucio' 'Est_Cadastre_Locals_Sup'
#  'h2mave-semestralt1b' 'h2mave-anualt1b' 'h2mave-totalt5b'
#  'h2mave-totalt2b' 'Est_Padro_Domicilis_Nacionalitat' 'h2mallo-evolucio'
#  'Est_Padro_Sexe' 'Est_Demo_Emigrants_Sexe' 'Est_Padró_Nacionalitat_Sexe'
#  'h2mave-totalt4b' 'Est_Vehicles_Cilindrada_Motos' 'h2mave-totalt3b'
#  'Est_Demo_Taxa_Immigracio' 'h2mallo-a' 'h2mave-semestralt3b'
#  'h2mave-anualt2b' 'Est_Demo_Taxa_Baixa_Inscripció_Indeguda'
#  'h2mave-anualt3b' 'Est_Padro_Domicilis_menors _18_anys'
#  'Est_Demo_Immigrants_Sexe' 'Est_Renda_Familiar' 'h2mave-totalt1b'
#  'h2mave-semestralt2b' 'locve-evolucio' 'Est_Demo_Naixements_Sexe'
#  'Est_Padro_Nivell_Academic_Sexe' 'locve-a'
#  'Est_Demo_Altes_Omissio_Edat_Quinquenal'
#  'Est_Padró_Viu_Sola_Edat_Quinquenal' 'Est_Cadastre_Locals_Prop'
#  'locllo-a' 'Est_Cadastre_Locals_Valors_Total_Unitaris'
#  'Est_Padro_Lloc_naixement_CCAA_Sexe' 'Est_Demo_Taxa_Migracio_Interna'
#  'Est_INE_Nacionalitat' 'Est_INE_Edat_Any_a_Any'
#  'Est_INE_Lloc_Naix_CCAA_Prov' 'Est_Superficie'
#  'Est_Vehicles_Antiguitat_Motos' 'Est_Cadastre_Locals_Us_Desti'
#  'Est_Vehicles_Tipus_Propietari_Motos' 'Est_Demo_Canvi_Domicili_Sexe'
#  'Est_Demo_Taxa_Mortalitat' 'Est_Demo_Taxa_Emigracio'
#  'Est_Demo_Baixes_Sexe' 'Est_Demo_Taxa_Natalitat'
#  'Est_Eleccions_Locals_Seccio_Censal'
#  'Est-Eleccions_Autonomiques_Seccio_Censal' 'Est_INE_Sexe'
#  'Est_Padro_Edat_Quinquenal_Nacionalitat_Sexe' 'Est_Padró_Edat_Any_a_Any'
#  'Est_Eleccions_Europees_Seccio_Censal' 'Est_Vehicles_Antiguitat_Turismes'
#  'Est_Vehicles_Tipologia_Parc_Vehicles'
#  'Est_Vehicles_Nacionalitat_Propietari_Motos' 'Est_Demo_Taxa_Alta_Omissio'
#  'Est_Padro_Domicilis_Nombre_Persones' 'Est_Densitat'
#  'Est_Padro_Domicilis_18_a_64_anys' 'Est_Padro_Domicilis_Estructura'
#  'Est_Padro_Domicilis_Edat_Mitjana_Nacionalitat'
#  'Est_Padro_Domicilis_65_mes_anys' 'Est_Vehicles_Potencia_Fiscal_Turismes'
#  'Est_Vehicles_Tipus_Propietari' 'CARTA_ARQUEOLOGICA_BARCELONA'
#  'AGENDA_DIARIA' 'EQUIPAMENT_ADMINISTRACIO' 'EQUIPAMENT_CULTURA_I_LLEURE'
#  'EQUIPAMENT_RESTAURANTS' 'EQUIPAMENT_COMPANYIES_DE_SERVEIS'
#  'EQUIPAMENT_ANIMALS_I_PLANTES'
#  'EQUIPAMENT_MITJANS_DE_COMUNICACIO_I_SERVEIS_RELACIONATS'
#  'EQUIPAMENT_MEDI_AMBIENT_I_SERVEIS_RELACIONATS' 'EQUIPAMENT_ESPORTS'
#  'EQUIPAMENT_MERCATS_I_CENTRES_COMERCIALS'
#  'EQUIPAMENT_CENTRES_D_INFORMACIO' 'EQUIPAMENT_SERVEIS_SOCIALS'
#  'EQUIPAMENT_CEMENTIRIS_I_SERVEIS_RELACIONATS'
#  'EQUIPAMENT_SERVEIS_RELIGIOSOS' 'EQUIPAMENT_SANITAT'
#  'EQUIPAMENT_EDUCACIO' 'CATALEG_OPENDATA' 'EQUIPAMENT_ASSOCIACIONS'
#  'TRANSIT_RELACIO_TRAMS_PER_ITINERARI' 'TRANSIT_RELACIO_TRAMS'
#  'TAULA_MAP_ILLA' 'TAULA_SEGIMON' 'TAULA_MAP_SCENSAL' 'TAULA_DIRELE'
#  'TAULA_DIRELE_SEC_CENS' 'MAPA_BASE_GUIA' 'TRAMS'
#  'MAPA_DE_RETOLACIO_DE_CARRERS' 'MAPA_BASE_TOPOGRAFIC'
#  'MAPA_DE_LA_MALLA_DE_FULLS_UTM' 'MAPA_URBANISTIC' 'MAPA_BASE_DE_VIALITAT'
#  'MAPA_PARCELARI' 'FRASE' 'ITINERARIS']

# %%
cataleg = catalogo[['code', 'title', 'frequency', 'fuente', 'relationships_as_object']]

# %%
ds_mitja_mensual.to_csv('datasets/ds_mitja_mensual.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22636/1051067313.py in <module>
# ----> 1 ds_mitja_mensual.to_csv('datasets/ds_mitja_mensual.csv', index=False)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/ds_mitja_mensual.csv'
